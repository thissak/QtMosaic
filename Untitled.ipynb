# %%
import subprocess

# %%
import os

# %%
subprocess.run(["dir"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 subprocess.run(["dir"])
#
# File ~\anaconda3\envs\QtMosaic\lib\subprocess.py:501, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     498     kwargs['stdout'] = PIPE
#     499     kwargs['stderr'] = PIPE
# --> 501 with Popen(*popenargs, **kwargs) as process:
#     502     try:
#     503         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File ~\anaconda3\envs\QtMosaic\lib\subprocess.py:966, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     962         if self.text_mode:
# ...

# %%
os.popen('dir')

# %%
subprocess.run()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 subprocess.run()
#
# File ~\anaconda3\envs\QtMosaic\lib\subprocess.py:501, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     498     kwargs['stdout'] = PIPE
#     499     kwargs['stderr'] = PIPE
# --> 501 with Popen(*popenargs, **kwargs) as process:
#     502     try:
#     503         stdout, stderr = process.communicate(input, timeout=timeout)
#
# TypeError: Popen.__init__() missing 1 required positional argument: 'args'

# %%
cmd = "dir"

# %%
c = subprocess.run("dira", shell=True)

# %%
print(c)
# Out:
# CompletedProcess(args='dira', returncode=1)

# %%
c.returncode
# Out:
# 1

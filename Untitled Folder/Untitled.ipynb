# %%
print("hello")
# Out:
# hello

# %%
cmd = os.popen("c:\\configureMosaic.exe listconfigcmd").read().split(" ")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 cmd = os.popen("c:\\configureMosaic.exe listconfigcmd").read().split(" ")
#
# NameError: name 'os' is not defined

# %%
import os

# %%
cmd = os.popen("c:\\configureMosaic.exe listconfigcmd").read().split(" ")

# %%
cmd
# Out:
# ['c:\\configureMosaic.exe',
#  'set',
#  'rows=1',
#  'cols=1',
#  'res=2560,1600,165.000',
#  'gridPos=0,0',
#  'out=0,0',
#  'rotate=0',
#  '',
#  'nextgrid',
#  'rows=1',
#  'cols=1',
#  'res=3840,2160,60.000',
#  'gridPos=2560,0',
#  'out=0,1',
#  'rotate=0',
#  '']

# %%
try:
    cmd[:9].index('nextgrid')
except ValueError:
    print("It has not nextgrid")
# Out:
# It has not nextgrid

# %%
cmd[:9]
# Out:
# ['c:\\configureMosaic.exe',
#  'set',
#  'rows=1',
#  'cols=1',
#  'res=2560,1600,165.000',
#  'gridPos=0,0',
#  'out=0,0',
#  'rotate=0',
#  '']

# %%
cmd[0]
# Out:
# 'c:\\configureMosaic.exe'

# %%
cmd.index('set')
# Out:
# 1

# %%
cmd.index('nextgrid')
# Out:
# 9
